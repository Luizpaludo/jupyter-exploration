# %%
print("Hello, World")
# Out:
# Hello, World

# %%
print ("Introduce your self")
name = input("What is your name ?")
age = int(input("What is your age ?"))
major = input("What is your major ?")

print (f"Hi {name}, you are {age} years old, and your major is {major}.")
print ("Thank you for answering our questionnaire have a wonderful day")
# Out:
# Introduce your self
# What is your name ? luiz
# What is your age ? 40
# What is your major ? ai
# Hi luiz, you are 40 years old, and your major is ai.
# Have a wonderful day
